# %% [markdown]
# <a id="table_of_content"></a>

# %% [markdown]
# # Part 1: Bag-of-Words Exercises
#
# In the following, we will convert our corpus of 10-k documents into bag-of-words, and convert them into document vectors using Term-Frequency-Inverse-Document-Frequency (tf-idf) re-weighting. Afterward, we will compute sentiments and similarity metrics. Since we will be reusing our notebook, so the various sections are linked below:
#
# 1. <a href="#bag_of_word">Compute bag-of-words </a>: implement `bag_of_words` that converts tokenized words into a dictionary of word-counts
#
# 2. <a href="#sentiment">Sentiments </a>: using wordlists, compute positive and negative sentiments from bag-of-words. Implement `get_sentiment`
#
# For solutions, see [bagofwords_solutions.py](./bagofwords_solutions.py). You can load the functions by simply calling
#
# `from bagofwords_solutions import *`
#
# # Part 2: Document-Vector Exercises
#
# 3. <a href="#compute_idf">Compute idf </a>: computing the inverse document frequency, implement `get_idf`
#
# 4. <a href="#compute_tf">Compute tf </a>: computing the term frequency, implement `get_tf`
#
# 5. <a href="#doc_vector">Document vector </a>: using the functions `get_idf` and `get_tf`, compute a word_vector for each document in the corpus
# 6. <a href="#similarity">Similarities </a>: comparing two vectors, and compute cosine and jacard similarity metrics. Implement `get_cos` and `get_jac`
#
# For solutions, see [bagofwords_solutions.py](./bagofwords_solutions.py). You can load the functions by simply calling
#
# `from bagofwords_solutions import *`

# %% [markdown]
# ## 0. Initialization
#
# First we read in our 10-k documents

# %%
# download some excerpts from 10-K files
from download10k import get_files

CIK = {'ebay': '0001065088', 'apple':'0000320193', 'sears': '0001310067'}
get_files(CIK['ebay'], 'EBAY')
get_files(CIK['apple'], 'AAPL')
get_files(CIK['sears'], 'SHLDQ')


# get a list of all 10-ks in our directory
files=! ls *10k*.txt
print("10-k files: ",files)
files = [open(f,"r").read() for f in files]
# Out:
# downloading 10-Ks item 1A for CIK = 0001065088 ...
# downloading 10-Ks item 1A for CIK = 0000320193 ...
# writing AAPL_10k_2017.txt...
# writing AAPL_10k_2016.txt...
# downloading 10-Ks item 1A for CIK = 0001310067 ...
# 10-k files:  ['AAPL_10k_2016.txt', 'AAPL_10k_2017.txt', 'SHLDQ_10k_2014.txt', 'SHLDQ_10k_2015.txt', 'SHLDQ_10k_2016.txt', 'SHLDQ_10k_2017.txt']

# %% [markdown]
# here we define useful functions to tokenize the texts into words, remove stop-words, and lemmatize and stem our words

# %%
import numpy as np

# for nice number printing
np.set_printoptions(precision=3, suppress=True)

# tokenize and clean the text
import nltk
from nltk.stem import WordNetLemmatizer, SnowballStemmer
from collections import Counter
from nltk.corpus import stopwords
from nltk import word_tokenize
from nltk.tokenize import RegexpTokenizer
# tokenize anything that is not a number and not a symbol
word_tokenizer = RegexpTokenizer(r'[^\d\W]+')

nltk.download('stopwords')
nltk.download('wordnet')


sno = SnowballStemmer('english')
wnl = WordNetLemmatizer()

# get our list of stop_words
nltk.download('stopwords')
stop_words = set(stopwords.words('english')) 
# add some extra stopwords
stop_words |= {"may", "business", "company", "could", "service", "result", "product", 
               "operation", "include", "law", "tax", "change", "financial", "require",
               "cost", "market", "also", "user", "plan", "actual", "cash", "other",
               "thereto", "thereof", "therefore"}

# useful function to print a dictionary sorted by value (largest first by default)
def print_sorted(d, ascending=False):
    factor = 1 if ascending else -1
    sorted_list = sorted(d.items(), key=lambda v: factor*v[1])
    for i, v in sorted_list:
        print("{}: {:.3f}".format(i, v))

# convert text into bag-of-words
def clean_text(txt):
    lemm_txt = [ wnl.lemmatize(wnl.lemmatize(w.lower(),'n'),'v') \
                for w in word_tokenizer.tokenize(txt) if \
                w.isalpha() and w not in stop_words ]
    return [ sno.stem(w) for w in lemm_txt if w not in stop_words and len(w) > 2 ]

corpus = [clean_text(f) for f in files]
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Unzipping corpora/wordnet.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %% [markdown]
# <a id="bag_of_words"></a>

# %% [markdown]
# ## 1. Bag-of-Words

# %% [markdown]
# Implement a function that converts a list of tokenized words into bag-of-words, i.e. a dictionary that outputs the frequency count of a word
#
# ** python already provide the `collections.Counter` class to perform this, but I encourage you to implement your own function as an exercise
#
# <a href="#table_of_content">back to top</a>

# %%
from collections import defaultdict

def bag_of_words(words):
    bag = defaultdict(int)
    for i in words:
        bag[i] +=1
    return bag

# %% [markdown]
# <a id="sentiment"></a>

# %% [markdown]
# ## 2. Sentiments
# Count the fraction of words that appear in a wordlist, returning a sentiment score between 0 and 1:
#
# $$
# \textrm{score} = \frac{\textrm{Number of words in document matching wordlist}}{\textrm{Number of words in document}}
# $$
#
# Implement the score in a function `get_sentiment(words, wordlist)`, where words is a list of words. Feel free to use the previous `bag_of_words` function.
# (*for extra challenge, try to code the function in one-line*)
#
# Here, I've included a positive and negative wordlist that I constructed by hand. Due to copyright issues, we are not able to provide other commonly used wordlists. I encourage you to try out different wordlists on your own.
#
# <a href="#table_of_content">back to top</a>

# %%
# load wordlist first
import pickle

with open('positive_words.pickle', 'rb') as f:
    positive_words = pickle.load(f)
    # also need to stem and lemmatize the text
    positive_words = set(clean_text(" ".join(positive_words)))
    
with open('negative_words.pickle', 'rb') as f:
    negative_words = pickle.load(f)
    negative_words = set(clean_text(" ".join(negative_words)))
    
# check out the list
print("positive words: ", positive_words)
print(" ")
print("negative words: ", negative_words)
# Out:
# positive words:  {'award', 'benign', 'honor', 'achiev', 'nobli', 'pleasant', 'support', 'exhilar', 'perfect', 'solv', 'enrich', 'gain', 'respect', 'surpass', 'resolv', 'surg', 'innov', 'enchant', 'nurtur', 'nourish', 'growth', 'appeal', 'power', 'laud', 'clean', 'exuber', 'origin', 'rich', 'congratul', 'strength', 'outstand', 'visionari', 'best', 'winner', 'fantast', 'revolutionari', 'legendari', 'miracul', 'happili', 'heal', 'popular', 'boon', 'prestigi', 'accept', 'nobil', 'appreci', 'prosper', 'fortun', 'advanc', 'gift', 'great', 'earnest', 'lead', 'excel', 'progress', 'distinct', 'stupend', 'champion', 'jubil', 'cheer', 'terrif', 'except', 'clear', 'benevol', 'eleg', 'invent', 'adorn', 'command', 'miracl', 'success', 'promin', 'applaus', 'exemplifi', 'monument', 'bright', 'bliss', 'distinguish', 'higher', 'product', 'passion', 'wow', 'reliev', 'high', 'upbeat', 'actual', 'vibrant', 'resourc', 'revolut', 'courag', 'acclaim', 'good', 'benefit', 'improv', 'special', 'marvel', 'incred', 'stabil', 'superb', 'trendi', 'lucrat', 'better', 'fascin', 'forefront', 'effici', 'enhanc', 'recoveri', 'flourish', 'glow', 'plenti', 'awesom', 'extraordinarili', 'aptitud', 'approv', 'safe', 'strong', 'opportun', 'paradis', 'upstand', 'elev', 'prodigi', 'reward', 'extraordinari', 'fresh', 'harmoni', 'polish', 'amelior', 'tremend', 'abund', 'attain', 'complet', 'groundbreak', 'love', 'merit', 'reinforc', 'solut', 'attract', 'effect', 'enthusiasm', 'stabl', 'trendili', 'admir', 'amaz', 'independ', 'master', 'rebound', 'endors', 'generous', 'prestig', 'profici', 'compliment', 'ador', 'buoy', 'insight', 'exquisit', 'inspir', 'loyalti', 'wholesom', 'glamor', 'succeed', 'benefici', 'talent', 'refresh', 'bless', 'championship', 'bolster', 'meritori', 'posit', 'creativ', 'restor', 'beauti', 'happi', 'revolution', 'win', 'recov', 'relief', 'booster', 'brilliant', 'loyal', 'belov', 'transform', 'ingeni', 'nobl', 'fabul', 'flawless', 'devot', 'virtuous', 'dazzl', 'wonder', 'brighter', 'victori', 'optim', 'esteem', 'astonish', 'favor', 'motiv', 'wealth', 'divin', 'impress', 'celebr', 'spring', 'persever', 'optimist', 'delight', 'satisfi', 'surmount', 'magic', 'famous', 'boost', 'prais', 'satisfactori', 'outperform', 'wealthi', 'accomplish', 'dynam', 'encourag'}
#
# negative words:  {'powerless', 'tragedi', 'handicap', 'perjuri', 'dismal', 'disqualif', 'fail', 'falsifi', 'embezzl', 'imped', 'misfortun', 'unattain', 'crime', 'dysfunct', 'ruin', 'hurt', 'fraud', 'forfeit', 'corrupt', 'hatr', 'unabl', 'illeg', 'scandal', 'harder', 'slow', 'uncontrol', 'disgust', 'defianc', 'cataclysm', 'dissolv', 'fire', 'wors', 'imposs', 'thiev', 'peril', 'abhorr', 'sacrifici', 'lag', 'disclaim', 'worst', 'convict', 'apathi', 'incid', 'violent', 'difficult', 'curs', 'avoid', 'fear', 'horrend', 'violat', 'conced', 'revolt', 'tragic', 'unscrupul', 'bankrupt', 'unwelcom', 'devast', 'undermin', 'intimid', 'confus', 'gloomi', 'gloom', 'disabl', 'blow', 'refus', 'scourg', 'unauthor', 'erron', 'unpopular', 'ineffici', 'lazi', 'disqualifi', 'untal', 'accid', 'default', 'inept', 'eros', 'trial', 'deni', 'uneth', 'manipul', 'inferior', 'exacerb', 'excess', 'fiasco', 'doom', 'pessimist', 'unhappi', 'afflict', 'untrustworthi', 'insan', 'disadvantag', 'erod', 'lazili', 'unlaw', 'malfunct', 'contempt', 'disapprov', 'advers', 'invalid', 'incident', 'pressur', 'worrisom', 'rotten', 'null', 'unstabl', 'objection', 'appal', 'boycott', 'damag', 'bribe', 'conflict', 'reject', 'vile', 'argument', 'arrest', 'danger', 'cloudi', 'calam', 'escal', 'woe', 'breakabl', 'steal', 'destroy', 'hate', 'nastili', 'blame', 'critic', 'fruitless', 'disturb', 'urgent', 'lie', 'oppress', 'fault', 'subpoena', 'wreck', 'wrong', 'bankruptci', 'unnecessari', 'terribl', 'anomali', 'inviabl', 'odious', 'deplor', 'unnecessarili', 'demot', 'guilt', 'mockeri', 'complaint', 'suspend', 'injuri', 'sorrow', 'collus', 'nefari', 'desol', 'headach', 'foul', 'nasti', 'fatal', 'doubt', 'abhor', 'harsh', 'trivial', 'offens', 'delay', 'distress', 'dead', 'downgrad', 'hostil', 'horrid', 'disinterest', 'unproduct', 'blackmail', 'catastroph', 'defiant', 'termin', 'complic', 'declin', 'atroci', 'insolv', 'frustrat', 'stress', 'sue', 'closur', 'insol', 'distast', 'low', 'wick', 'disfavor', 'inconveni', 'bust', 'malign', 'repudi', 'lawsuit', 'fals', 'failur', 'worri', 'incap', 'degrad', 'aw', 'imperil', 'pollut', 'terror', 'crack', 'harrow', 'dirti', 'dull', 'exploit', 'indign', 'recal', 'devalu', 'argu', 'breach', 'cutback', 'leak', 'repuls', 'doomsday', 'upset', 'hardest', 'object', 'discredit', 'outlaw', 'scorn', 'aggrav', 'attenu', 'unworthi', 'murder', 'obsolesc', 'dread', 'uninspir', 'dark', 'overpay', 'counterfeit', 'postpon', 'ban', 'ugli', 'weak', 'obstruct', 'negat', 'abandon', 'error', 'horribl', 'misappli', 'impot', 'taint', 'neglect', 'incompat', 'worsen', 'deter', 'evil', 'notori', 'contradict', 'indict', 'misappl', 'harsher', 'accident', 'hardship', 'investig', 'desper', 'disast', 'collud', 'content', 'deterior', 'debt', 'apathet', 'deris', 'ridicul', 'pessim', 'loot', 'lower', 'agoni', 'penalti', 'malic', 'impoverish', 'blacklist', 'diminish', 'storm', 'death', 'suspens', 'vice', 'wast', 'crash', 'miseri', 'nuisanc', 'thieveri', 'obnoxi', 'unfruit', 'panic', 'jail', 'depress', 'decept', 'delus', 'inabl', 'flaw', 'lack', 'gruesom', 'abomin', 'difficulti', 'underwhelm', 'shadi', 'usurp', 'strike', 'hamper', 'bottleneck', 'harm', 'impeach', 'unsettl', 'injur', 'halt', 'hinder', 'litig', 'shutdown', 'instabl', 'illicit', 'turbul', 'sacrific', 'strain', 'impedi', 'unfavor', 'shrink', 'crisi', 'burden', 'ineffect', 'rot', 'uneffect', 'unfortun', 'fraudul', 'shame', 'abnorm', 'obsolet', 'horror', 'accus', 'attrit', 'plea', 'fright', 'vilifi', 'repugn', 'nullifi', 'balk', 'close', 'antiqu', 'deprav', 'desist', 'empti', 'plung', 'threat', 'misus', 'condemn', 'guilti', 'troubl', 'ceas', 'dampen', 'hard', 'hazard', 'vulgar', 'disregard', 'unneed', 'deplet', 'dirtili', 'faulti', 'retreat', 'temper', 'unattract', 'suspici', 'drain', 'weaken', 'illiquid', 'troublesom', 'weari', 'forgeri', 'renounc', 'exhaust', 'sever', 'unfair', 'underperform', 'discourag', 'break', 'kill'}

# %%
def get_sentiment(txt, wordlist):
    matching_words = [w for w in txt if w in wordlist ]
    return len(matching_words)/len(txt)

# %%
# test your function
positive_sentiments = np.array([ get_sentiment(c, positive_words) for c in corpus ])
print(positive_sentiments)

negative_sentiments = np.array([ get_sentiment(c, negative_words) for c in corpus ])
print(negative_sentiments)
# Out:
# [ 0.034  0.034  0.051  0.049  0.037  0.04 ]
# [ 0.056  0.054  0.063  0.062  0.06   0.059]

# %% [markdown]
# **before continuing part 2, go through the lesson material first!**

# %% [markdown]
# # Part 2 Document Vector Exercises
#
# ## 3. Computer idf
# Given a corpus, or a list of bag-of-words, we want to compute for each word $w$, the inverse-document-frequency, or ${\rm idf}(w)$. This can be done in a few steps:
#
# 1. Gather a set of all the words in all the bag-of-words (python set comes in handy, and the union operator `|` is useful here)
#
#
# 2. Loop over each word $w$, and compute ${\rm df}_w$, the number of documents where this word appears at least once. A dictionary is useful for keeping track of ${\rm df}_w$
#
#
# 3. After computing ${\rm df}_w$, we can compute ${\rm idf}(w)$. There are usually two possibilities, the simplest one is
# $${\rm idf}(w)=\frac{N}{{\rm df}_w}$$
# Where $N$ is the total number of documents in the corpus and $df_w$ the number of documents that contain the word $w$. Frequently, a logarithm term is added as well
# $${\rm idf}(w)=\log\frac{N}{{\rm df}_w}$$
# One issue with using the logarithm is that when ${\rm df}_w = N$, ${\rm idf}(w)=0$, indicating that words common to all documents would be ignored. If we don't want this behavior, we can define ${\rm idf}(w)=\log\left(1+N/{\rm df}_w\right)$ or ${\rm idf}(w)=1+\log\left(N/{\rm df}_w\right)$ instead. For us, we'll not use the extra +1 for ${\rm idf}$.
#
# In the following, define a function called `get_idf(corpus, include_log=True)` that computes ${\rm idf}(w)$ for all the words in a corpus, where `corpus` for us is a processed list of bag-of-words (stemmed and lemmatized). The optional parameter `include_log` includes the logarithm in the computation.
#
# <a href="#table_of_content">back to top</a>

# %%
def get_idf(corpus, include_log=True):
    N = len(corpus)
    freq = defaultdict(int)
    words = set()
    for c in corpus:
        words |= set(c)
        
    for w in words:
        freq[w] = sum([ w in c for c in corpus])

    if include_log:
        return { w:np.log(N/freq[w]) for w in freq }
    else:
        return { w:N/freq[w] for w in freq }

# %% [markdown]
# You should expect to see many idf values = 0! This is by design, because we have ${\rm idf}(w)=\log N_d/{\rm df}_w$ and $N_d/{\rm df}_w=1$ for the most common words!

# %%
# test your code
idf=get_idf(corpus)
print_sorted(idf, ascending=True)
# Out:
# regardless: 0.000
# term: 0.000
# profit: 0.000
# loss: 0.000
# transport: 0.000
# disrupt: 0.000
# proceed: 0.000
# lead: 0.000
# corpor: 0.000
# duti: 0.000
# time: 0.000
# valu: 0.000
# government: 0.000
# secur: 0.000
# high: 0.000
# defend: 0.000
# improv: 0.000
# number: 0.000
# key: 0.000
# choos: 0.000
# televis: 1.792
# outlet: 1.792
# temperatur: 1.792
# discontinu: 1.792
# northern: 1.792
# divers: 1.792
# know: 1.792
# creditor: 1.792
# dominion: 1.792
# file: 1.792
# issuer: 1.792
# elig: 1.792
# capabl: 1.792
# interchang: 1.792
# microprocessor: 1.792
# strive: 1.792
# disposit: 1.792
# lesser: 1.792
# defici: 1.792
# revolv: 1.792
# ceo: 1.792
# estim: 1.792
# turnov: 1.792
# pii: 1.792
# help: 1.792
# processor: 1.792
# world: 1.792
# defin: 1.792
# handset: 1.792
# member: 1.792
# reform: 1.792
# headcount: 1.792
# bargain: 1.792
# calcul: 1.792
# encrypt: 1.792
# transpar: 1.792
# memori: 1.792
# money: 1.792
# sanction: 1.792
# decker: 1.792
# denial: 1.792
# unrest: 1.792
# intent: 1.792
# decemb: 1.792
# poss: 1.792
# lewi: 1.792
# except: 1.792
# cyber: 1.792
# disgorg: 1.792
# thereaft: 1.792
# letter: 1.792
# array: 1.792
# netherland: 1.792
# contractu: 1.792
# allianc: 1.792
# octob: 1.792
# medic: 1.792
# align: 1.792
# await: 1.792
# presid: 1.792
# absolut: 1.792
# creditworthi: 1.792
# prolong: 1.792
# summer: 1.792
# back: 1.792
# expir: 1.792
# petroleum: 1.792
# secret: 1.792
# stronger: 1.792
# faulti: 1.792
# lien: 1.792
# unreason: 1.792
# suspici: 1.792
# signal: 1.792
# updat: 1.792
# defens: 1.792
# warm: 1.792

# %% [markdown]
# <a id="compute_tf"></a>

# %% [markdown]
# ## 4. Compute tf
#
# Below we will compute ${\rm tf}(w,d)$, or the term frequency for a given word $w$, in a given document $d$. Since our ultimate goal is to compute a document vector, we'd like to keep a few things in mind
#
# 1. Store the ${\rm tf}(w, d)$ for each word in a document as a dictionary
# 2. Even when a word doesn't appear in the document $d$, we still want to keep a $0$ entry in the dictionary. This is important when we convert the dictionary to a vector, where zero entries are important
#
#
# There are multiple definitions for ${\rm tf}(w,d)$, the simplest one is
#
# $$
# {\rm tf}(w,d)=\frac{f_{w,d}}{a_d}
# $$
#
# where $f_{w,d}$ is the number of occurence of the word $w$ in the document $d$, and $a$ the average occurence of all the words in that document for normalization. Just like ${\rm idf}(w)$, a logarithm can be added
#
# $$
# {\rm tf}(w,d)=\begin{cases}
# \frac{1+\log f_{w,d}}{1+\log a_d} & f_{w,d} > 0 \\
# 0 & f_{w,d} = 0 \\
# \end{cases}
# $$
#
# Implement the function `get_df(txt, include_log=True)` that computes ${\rm tf}(w,d)$ for each word in the document (returns a defaultdict(int), so that when supplying words not in the document the dictionary will yield zero instead of an error). Also include the optional parameter `include_log` that enables the additional logarithm term in the computation. I suggest also adding a function called `_tf` that computes the function above.
#
# <a href="#table_of_content">back to top</a>

# %%
import numpy as np
from math import *

def _tf(freq, avg, include_log=True):
    if include_log:
        return 0 if freq == 0 else (1+log(freq))/(1+log(avg))
    else:
        return freq/avg

def get_tf(txt, include_log=True):
    freq = bag_of_words(txt)
    avg = np.mean(list(freq.values()))
    tf = {w:_tf(f,avg, include_log) for w,f in freq.items()}
    return defaultdict(int, tf)

# %%
tfs = [ get_tf(c) for c in corpus ]
print_sorted(tfs[0])
# Out:
# affect: 2.146
# oper: 2.103
# advers: 2.088
# condit: 2.080
# materi: 2.080
# compon: 1.930
# develop: 1.918
# price: 1.894
# third: 1.882
# risk: 1.856
# parti: 1.856
# signific: 1.828
# new: 1.782
# certain: 1.782
# limit: 1.782
# manufactur: 1.766
# custom: 1.749
# applic: 1.749
# continu: 1.731
# softwar: 1.731
# current: 1.693
# futur: 1.693
# addit: 1.672
# subject: 1.672
# demand: 1.651
# compet: 1.651
# time: 1.651
# avail: 1.651
# foreign: 1.651
# credit: 1.628
# sale: 1.628
# competit: 1.628
# assur: 1.628
# effect: 1.604
# valu: 1.579
# increas: 1.579
# technolog: 1.579
# margin: 1.579
# relat: 1.579
# distribut: 1.579
# key: 1.552
# invest: 1.552
# mani: 1.552
# provid: 1.552
# carrier: 1.552
# resel: 1.552
# retail: 1.552
# intern: 1.552
# currenc: 1.523
# substanti: 1.523
# network: 1.523
# manag: 1.523
# econom: 1.492
# depend: 1.492
# industri: 1.492
# channel: 1.492
# devic: 1.492
# content: 1.492
# term: 1.492
# negat: 1.459
# supplier: 1.459
# competitor: 1.459
# patent: 1.459
# iphon: 1.459
# vendor: 1.459
# regul: 1.459
# perform: 1.422
# sell: 1.422
# system: 1.422
# obtain: 1.422
# receiv: 1.422
# associ: 1.422
# trade: 1.422
# uncertainti: 1.382
# factor: 1.382
# failur: 1.382
# loss: 1.382
# stock: 1.382
# abil: 1.382
# success: 1.382
# infring: 1.382
# use: 1.382
# mac: 1.382
# experi: 1.382
# inventori: 1.382
# suppli: 1.382
# store: 1.382
# licens: 1.382
# caus: 1.382
# consum: 1.338
# dollar: 1.338
# partner: 1.338
# purchas: 1.338
# secur: 1.338
# rate: 1.338
# high: 1.338
# hardwar: 1.338
# offer: 1.338
# reason: 1.338
# global: 1.289
# expect: 1.289
# general: 1.289
# event: 1.289
# delay: 1.289
# expens: 1.289
# gross: 1.289
# introduct: 1.289
# maintain: 1.289
# base: 1.289
# non: 1.289
# agreement: 1.289
# natur: 1.289
# issu: 1.289
# contract: 1.289
# fluctuat: 1.289
# locat: 1.289
# ipad: 1.289
# disrupt: 1.289
# action: 1.289
# asset: 1.233
# volatil: 1.233
# number: 1.233
# impact: 1.233
# design: 1.233
# intellectu: 1.233
# properti: 1.233
# comput: 1.233
# platform: 1.233
# mobil: 1.233
# communic: 1.233
# medium: 1.233
# enter: 1.233
# cellular: 1.233
# due: 1.233
# accept: 1.233
# anticip: 1.233
# order: 1.233
# give: 1.233
# inform: 1.233
# sever: 1.233
# right: 1.233
# claim: 1.233
# revenu: 1.233
# renew: 1.168
# deriv: 1.168
# exchang: 1.168
# would: 1.168
# rapid: 1.168
# part: 1.168
# belief: 1.168
# solut: 1.168
# person: 1.168
# face: 1.168
# potenti: 1.168
# exist: 1.168
# digit: 1.168
# well: 1.168
# upgrad: 1.168
# product: 1.168
# commit: 1.168
# unfavor: 0.709
# place: 0.709
# equival: 0.709
# market: 0.709
# restat: 0.709
# statement: 0.709
# investig: 0.709
# end: 0.709
# director: 0.709
# state: 0.709
# outcom: 0.709
# worldwid: 0.419
# postpon: 0.419
# tighter: 0.419
# unemploy: 0.419
# news: 0.419
# sinc: 0.419
# influenc: 0.419
# fuel: 0.419
# energi: 0.419
# real: 0.419
# estat: 0.419
# mortgag: 0.419
# healthcar: 0.419
# macroeconom: 0.419
# behavior: 0.419
# turmoil: 0.419
# bank: 0.419
# tighten: 0.419
# counterparti: 0.419
# treasuri: 0.419
# gain: 0.419
# revalu: 0.419
# debt: 0.419
# balanc: 0.419
# assign: 0.419
# character: 0.419
# downward: 0.419
# pressur: 0.419
# cycl: 0.419
# evolv: 0.419
# characterist: 0.419
# sensit: 0.419
# heavili: 0.419
# marketplac: 0.419
# near: 0.419
# entir: 0.419
# copyright: 0.419
# trademark: 0.419
# mark: 0.419
# contrast: 0.419
# primarili: 0.419
# peripher: 0.419
# broader: 0.419
# instal: 0.419
# stronger: 0.419
# particular: 0.419
# smb: 0.419
# enterpris: 0.419
# creativ: 0.419
# internet: 0.419
# smaller: 0.419
# simpler: 0.419
# tradit: 0.419
# domin: 0.419
# notabl: 0.419
# function: 0.419
# unauthor: 0.419
# copi: 0.419
# establish: 0.419
# featur: 0.419
# altern: 0.419
# illegitim: 0.419
# recent: 0.419
# breadth: 0.419
# littl: 0.419
# even: 0.419
# intensifi: 0.419
# approach: 0.419
# seamless: 0.419
# work: 0.419
# integr: 0.419
# introduc: 0.419
# earli: 0.419
# accord: 0.419
# ultim: 0.419
# becom: 0.419
# obsolet: 0.419
# accru: 0.419
# fee: 0.419
# reserv: 0.419
# review: 0.419
# live: 0.419
# whenev: 0.419
# indic: 0.419
# recover: 0.419
# equal: 0.419
# unpredict: 0.419
# obsolesc: 0.419
# consist: 0.419
# normal: 0.419
# acquir: 0.419
# combin: 0.419
# open: 0.419
# project: 0.419
# day: 0.419
# incorrect: 0.419
# produc: 0.419
# pattern: 0.419
# suffici: 0.419
# enclosur: 0.419
# optic: 0.419
# drive: 0.419
# asic: 0.419
# commod: 0.419
# extend: 0.419
# expir: 0.419
# achiev: 0.419
# discuss: 0.419
# subhead: 0.419
# particip: 0.419
# rest: 0.419
# util: 0.419
# constraint: 0.419
# yield: 0.419
# matur: 0.419
# instead: 0.419
# constrain: 0.419
# transport: 0.419
# uncertain: 0.419
# diminish: 0.419
# flexibl: 0.419
# adher: 0.419
# code: 0.419
# reimburs: 0.419
# pursuant: 0.419
# facil: 0.419
# extern: 0.419
# california: 0.419
# texa: 0.419
# czech: 0.419
# republ: 0.419
# germani: 0.419
# israel: 0.419
# malaysia: 0.419
# netherland: 0.419
# philippin: 0.419
# taiwan: 0.419
# thailand: 0.419
# singapor: 0.419
# militari: 0.419
# commerci: 0.419
# owner: 0.419
# total: 0.419
# usag: 0.419
# rule: 0.419
# expand: 0.419
# reach: 0.419
# manner: 0.419
# forc: 0.419
# lessen: 0.419
# piraci: 0.419
# alleg: 0.419
# need: 0.419
# aspect: 0.419
# issuanc: 0.419
# possibl: 0.419
# unknow: 0.419
# notifi: 0.419
# vigor: 0.419
# pend: 0.419
# evalu: 0.419
# consid: 0.419
# desir: 0.419
# temporari: 0.419
# perman: 0.419
# prohibit: 0.419
# opinion: 0.419
# know: 0.419
# other: 0.419
# scope: 0.419
# valid: 0.419
# engag: 0.419
# protract: 0.419
# modifi: 0.419
# choos: 0.419
# buy: 0.419
# discontinu: 0.419
# strength: 0.419
# generat: 0.419
# question: 0.419
# prospect: 0.419
# devot: 0.419
# microsoft: 0.419
# adob: 0.419
# googl: 0.419
# compel: 0.419
# unlik: 0.419
# app: 0.419
# absenc: 0.419
# curtail: 0.419
# keep: 0.419
# dissatisfi: 0.419
# rather: 0.419
# effort: 0.419
# suffer: 0.419
# nation: 0.419
# catalogu: 0.419
# narrow: 0.419
# weak: 0.419
# expans: 0.419
# conflict: 0.419
# discourag: 0.419
# select: 0.419
# placement: 0.419
# display: 0.419
# space: 0.419
# rang: 0.419
# five: 0.419
# ten: 0.419
# profil: 0.419
# venu: 0.419
# brand: 0.419
# awar: 0.419
# vehicl: 0.419
# element: 0.419
# size: 0.419
# closur: 0.419
# poor: 0.419
# termin: 0.419
# macro: 0.419
# construct: 0.419
# challeng: 0.419
# environ: 0.419
# ongo: 0.419
# origin: 0.419
# contempl: 0.419
# acquisit: 0.419
# endeavor: 0.419
# involv: 0.419
# distract: 0.419
# assum: 0.419
# inadequ: 0.419
# capit: 0.419
# unidentifi: 0.419
# discov: 0.419
# dilig: 0.419
# ventur: 0.419
# inher: 0.419
# riski: 0.419
# problem: 0.419
# complex: 0.419
# bug: 0.419
# unexpect: 0.419
# interfer: 0.419
# intend: 0.419
# detect: 0.419
# lose: 0.419
# harm: 0.419
# voic: 0.419
# handset: 0.419
# impos: 0.419
# lock: 0.419
# mandat: 0.419
# bodi: 0.419
# test: 0.419
# modif: 0.419
# ceo: 0.419
# execut: 0.419
# team: 0.419
# skill: 0.419
# posit: 0.419
# talent: 0.419
# especi: 0.419
# silicon: 0.419
# valley: 0.419
# geopolit: 0.419
# commerc: 0.419
# economi: 0.419
# strong: 0.419
# power: 0.419
# terrorist: 0.419
# hostil: 0.419
# act: 0.419
# disput: 0.419
# creat: 0.419
# ineffici: 0.419
# chain: 0.419
# pandem: 0.419
# stringent: 0.419
# travel: 0.419
# freight: 0.419
# headquart: 0.419
# recoveri: 0.419
# resum: 0.419
# earthquak: 0.419
# theft: 0.419
# fraud: 0.419
# malici: 0.419
# mobilem: 0.419
# imped: 0.419
# transact: 0.419
# unintent: 0.419
# disclosur: 0.419
# step: 0.419
# address: 0.419
# concern: 0.419
# measur: 0.419
# among: 0.419
# accessori: 0.419
# across: 0.419
# configur: 0.419
# indirect: 0.419
# fourth: 0.419
# second: 0.419
# holiday: 0.419
# school: 0.419
# either: 0.419
# late: 0.419
# variat: 0.419
# volum: 0.419
# unrel: 0.419
# reflect: 0.419
# growth: 0.419
# investor: 0.419
# retent: 0.419
# without: 0.419
# import: 0.419
# export: 0.419
# corrupt: 0.419
# subsidiari: 0.419
# repatri: 0.419
# privaci: 0.419
# agent: 0.419
# instabl: 0.419
# versus: 0.419
# tariff: 0.419
# antidump: 0.419
# penalti: 0.419
# primari: 0.419
# australia: 0.419
# canada: 0.419
# throughout: 0.419
# world: 0.419
# full: 0.419
# convers: 0.419
# benefici: 0.419
# forward: 0.419
# recogn: 0.419
# domest: 0.419
# rat: 0.419
# deterior: 0.419
# heighten: 0.419
# worsen: 0.419
# outstand: 0.419
# collater: 0.419
# mitig: 0.419
# potion: 0.419
# unsecur: 0.419
# sub: 0.419
# monitor: 0.419
# prior: 0.419
# annual: 0.419
# form: 0.419
# describ: 0.419
# class: 0.419
# complaint: 0.419
# dismiss: 0.419
# comprehens: 0.419
# name: 0.419
# sec: 0.419
# enforc: 0.419
# settl: 0.419
# remedi: 0.419
# ordinari: 0.419
# yet: 0.419
# divers: 0.419
# attent: 0.419
# recognit: 0.419
# consider: 0.419
# monetari: 0.419
# relief: 0.419
# safeti: 0.419
# safe: 0.419
# dispos: 0.419
# recycl: 0.419
# provinc: 0.419
# north: 0.419
# america: 0.419
# unit: 0.419
# statutori: 0.419
# valuat: 0.419
# defer: 0.419
# administr: 0.419
# congress: 0.419
# regular: 0.419
# ass: 0.419
# likelihood: 0.419
# adequaci: 0.419
# self: 0.419
# unforeseen: 0.419
# catastroph: 0.419

# %% [markdown]
# <a id="doc_vector"></a>

# %% [markdown]
# ## 5. Document Vector
# Combine the implementation for ${\rm tf}(w,d)$ and ${\rm idf}(w)$ to compute a word-vector for each document in a corpus. Don't forget the zero-padding that is needed when a word appears in some document but not others.
#
# Implmenet the function `get_vectors(tf,idf)`, the input is the output computed by `get_tf` and `get_idf`
#
# (*optional challenge: implement in one line!*)
#
# <a href="#table_of_content">back to top</a>

# %%
def get_vector(tf, idf):
    return np.array([ tf[w]*idf[w] for w in idf ])

# %%
# test your code
doc_vectors = [ get_vector(tf, idf) for tf in tfs ]

for v in doc_vectors:
    print(v)
# Out:
# [ 0.75  0.    0.46 ...,  0.46  0.    0.  ]
# [ 0.     0.     0.784 ...,  0.784  0.     0.   ]
# [ 0.     0.     0.    ...,  0.     0.     0.218]
# [ 0.     0.     0.    ...,  0.     0.     0.217]
# [ 0.     0.     0.    ...,  0.     0.     0.212]
# [ 0.     0.     0.    ...,  0.     0.     0.168]

# %% [markdown]
# <a id ="similarity"></a>

# %% [markdown]
# ## 6. Similarity
#
# Given two word-vectors $\vec u$ (or $u_i$) and $\vec v$ (or $v_i$), corresponding to two documents, we want to compute different similarity metrics.
#
# 1. Cosine similarity, defined by
# $$
# {\rm Sim}_{\cos} = \frac{\vec u \cdot \vec v}{|\vec u| |\vec v|}
# $$
#
# 2. Jaccard similarity, defined by
# $$
# {\rm Sim}_{\rm Jaccard} = \frac{\sum_i \min\{u_i, v_i\}}{\sum_i \max\{u_i, v_i\}}
# $$
#
# Implement the function similarity as `sim_cis(u,v)` and `sim_jac(u,v)`. Utilize the numpy functions `numpy.linalg.norm` to compute norm of a vector and `np.dot` for computing dot-products. `np.minimum` and `np.maximum` are also useful vectorized pair-wise minimum and maximum functions.
#
# (*optional challenge: implement both functions in one line!*)
#
# <a href="#table_of_content">back to top</a>

# %%
from numpy.linalg import norm

def sim_cos(u,v):
    return np.dot(u,v)/(norm(u)*norm(v))

def sim_jac(u,v):
    return np.sum(np.minimum(u,v))/np.sum(np.maximum(u,v))

# %%
# test your co
# compute all the pairwise similarity metrics
size = len(doc_vectors)
matrix_cos = np.zeros((size,size))
matrix_jac = np.zeros((size,size))

for i in range(size):
    for j in range(size):
        u = doc_vectors[i]
        v = doc_vectors[j]
        matrix_cos[i][j] = sim_cos(u,v)
        matrix_jac[i][j] = sim_jac(u,v)
        
print("Cosine Similarity:")
print(matrix_cos)

print()
print("Jaccard Similarity:")
print(matrix_jac)
# Out:
# Cosine Similarity:
# [[ 1.     0.673  0.02   0.047  0.055  0.168]
#  [ 0.673  1.     0.016  0.05   0.066  0.186]
#  [ 0.02   0.016  1.     0.569  0.288  0.101]
#  [ 0.047  0.05   0.569  1.     0.361  0.136]
#  [ 0.055  0.066  0.288  0.361  1.     0.291]
#  [ 0.168  0.186  0.101  0.136  0.291  1.   ]]
#
# Jaccard Similarity:
# [[ 1.     0.544  0.014  0.029  0.04   0.13 ]
#  [ 0.544  1.     0.013  0.029  0.041  0.139]
#  [ 0.014  0.013  1.     0.56   0.283  0.057]
#  [ 0.029  0.029  0.56   1.     0.366  0.079]
#  [ 0.04   0.041  0.283  0.366  1.     0.141]
#  [ 0.13   0.139  0.057  0.079  0.141  1.   ]]

# %% [markdown]
# ### Good Job! You've finished all the exercises!
#
# Here is an optional bonus challenge. We often need to debug other people's code to figure out what's wrong. It's particularly difficult when the code doesn't give errors but computes the wrong quantity. Can you describe why the following implementations for some of the exercises above may be wrong? Highlight the words at the bottom to reveal the solutions!

# %%
def get_idf_wrong(corpus, include_log=True):
    freq = defaultdict(int)
    for c in corpus:
        for w in c:
            freq[w] += 1
        
    N = len(corpus)
    if include_log:
        return { w:log(N/freq[w]) for w in freq }
    else:
        return { w:N/freq[w] for w in freq }


def get_sentiment_wrong(txt, wordlist):
    matching_words = [ w for w in wordlist if w in txt ]
    return len(matching_words)/len(txt)

def get_vectors_wrong(tf, idf):
    return np.array([ tf[w]*idf[w] for w in tf ])

# %% [markdown]
# # Solutions
#
# Drag your mouse over the white space below this cell, and you'll see details about the solutions.  Or, if it's easier, just double-click on the white space below this cell, which will reveal the cell with hidden text.  Also, please check out the file [bagofwords_solutions.py](bagofwords_solutions.py).

# %% [markdown]
# <font color="white">
# Solution
#
# get_idf: the defaultdict freq here computes the total number of occurences in all the document. We only want to count it once when a word appears in a document. This may lead to a document frequency larger than N, leading to a negative idf!
#
# get_sentiment_wrong: if a word w appears twice in the document, it won't be counted properly!
#
# get_vectors_wrong: tf may not contain all the words in idf. We need zero padding for words that appear in idf but not in tf!
# </font>
